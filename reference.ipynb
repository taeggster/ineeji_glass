# %%
# 테스트 날짜 설정
start_date = datetime(2025, 10, 13, 0, 0, 0)
end_date = datetime(2026, 3, 29, 23, 59, 59)

# 필요한 데이터 필터링 (이미 데이터가 있으므로 필요한 시간대만 필터링)
df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

# 자동 제어 테스트 기간 정의 (사용자가 직접 확인 후 지정)
# 각 항목: (시작 날짜/시간, 종료 날짜/시간)
auto_control_periods = [
    (datetime.strptime('2025-10-13 14:18:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-13 18:10:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-14 09:05:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-14 18:30:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-15 09:50:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-15 13:15:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-20 13:40:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-20 21:15:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-21 14:47:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-21 21:02:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-22 13:50:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-22 20:20:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-23 15:36:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-23 21:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-24 12:30:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-24 21:55:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-27 13:57:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-27 23:41:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-28 15:38:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-28 23:46:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-29 10:01:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-29 20:47:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-30 13:58:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-30 16:39:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-10-31 10:24:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-10-31 21:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-03 16:47:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-04 02:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-04 13:23:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-04 22:15:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-05 14:45:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-05 21:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-07 13:09:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-07 21:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-10 14:05:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-10 21:08:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-11 14:15:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-11 20:54:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-12 13:17:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-12 21:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-13 13:47:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-13 20:27:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-14 15:36:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-14 17:35:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-15 08:44:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-15 10:31:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-17 13:31:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-17 14:24:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-17 15:51:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-17 20:46:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-18 13:50:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-18 21:09:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-19 17:05:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-20 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-20 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-21 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-21 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-22 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-22 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-23 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-23 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-24 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-24 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-25 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-25 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-25 04:18:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-25 08:05:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-25 21:20:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-26 09:12:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-26 21:13:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-27 03:14:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-27 21:34:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-28 09:17:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-29 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-29 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-29 00:36:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-11-30 05:53:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-11-30 06:45:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-01 09:01:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-01 20:55:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-02 08:58:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-02 21:02:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-03 10:05:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-03 20:13:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-04 13:35:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-05 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-05 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-05 07:10:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-05 15:18:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-05 22:18:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-16 11:35:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-17 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-17 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-17 18:54:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-22 09:20:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-22 09:50:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-22 15:20:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-23 00:46:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2025-12-23 14:56:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2025-12-23 16:38:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-05 10:50:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-05 20:09:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-06 14:03:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-06 20:49:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-14 09:09:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-14 12:17:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-14 13:57:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-14 16:10:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-23 09:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-23 18:54:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-28 10:29:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-28 17:29:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-29 09:22:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-29 16:30:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-30 09:52:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-31 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-01-31 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-01-31 04:51:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-02-02 08:57:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-02-03 00:00:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-02-03 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-02-03 01:39:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-02-03 14:23:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-02-03 16:13:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-02-04 09:26:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-02-04 15:54:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-02-06 11:24:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-02-06 13:05:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-09 10:16:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-09 16:57:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-10 08:57:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-10 20:58:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-11 09:12:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-11 21:16:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-12 09:10:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-12 22:17:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-13 08:49:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-13 20:37:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-16 08:56:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-16 20:23:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-17 13:13:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-17 16:54:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-20 08:53:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-20 23:59:30', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-21 00:00:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-21 18:09:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-22 08:49:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-22 17:54:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-23 09:05:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-23 16:55:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-24 09:04:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-24 16:31:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-25 08:57:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-25 10:22:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-26 17:01:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-26 19:05:00', '%Y-%m-%d %H:%M:%S')),
    (datetime.strptime('2026-03-28 10:55:00', '%Y-%m-%d %H:%M:%S'), datetime.strptime('2026-03-28 15:05:00', '%Y-%m-%d %H:%M:%S')),
    # 필요 시 테스트 기간 추가
]

# 'Runmode' 컬럼을 기본값 0 (수동 제어)으로 초기화
df['Runmode'] = 0

# df['Date']가 datetime 객체가 아니면 변환 (이미 로드 시 변환되었을 것으로 예상)
if not pd.api.types.is_datetime64_any_dtype(df['Date']):
    df['Date'] = pd.to_datetime(df['Date'])

# 정의된 자동 제어 기간에 해당하는 데이터의 'Runmode'를 1 (자동 제어)로 설정
for start_time, end_time in auto_control_periods:
    mask = (df['Date'] >= start_time) & (df['Date'] <= end_time)
    df.loc[mask, 'Runmode'] = 1

# 결과 확인: Runmode 별 데이터 개수
print("Runmode 분포:")
print(df['Runmode'].value_counts())

# %%
df['upper_limit'] = df['sv_arch'].values + 7.5
df['lower_limit'] = df['sv_arch'].values - 7.5
df['bt_upper_limit'] = df['sv_bt'].values + 2.5
df['bt_lower_limit'] = df['sv_bt'].values - 2.5
